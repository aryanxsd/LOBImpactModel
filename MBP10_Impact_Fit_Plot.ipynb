# %%
# --------------------------------------------------
# 📦 1️⃣ Import libraries & config
# --------------------------------------------------
import os
import zipfile
import pandas as pd
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

# 📌 Adjust these for your run:
#zip_files = [r"C:\Users\ajsty\OneDrive\Desktop\new\Data-20250726T124359Z-1-001.zip\Data\CRWV.zip", r"C:\Users\ajsty\OneDrive\Desktop\new\Data-20250726T124359Z-1-001.zip\Data\FROG.zip", r"C:\Users\ajsty\OneDrive\Desktop\new\Data-20250726T124359Z-1-001.zip\Data\SOUN.zip"]
symbol = ["CRWV", "FROG", "SOUN"]

# --------------------------------------------------

# %%
import os
import zipfile
import pandas as pd

symbol = "CRWV"
zip_path = r"C:\Users\ajsty\OneDrive\Desktop\new\Data-20250726T124359Z-1-001\Data\CRWV.zip"

def load_mbp10_events(zip_file, symbol):
    dfs = []
    with zipfile.ZipFile(zip_file, "r") as zf:
        for fname in zf.namelist():
            if fname.endswith(".csv") and symbol in fname:
                with zf.open(fname) as f:
                    try:
                        df = pd.read_csv(
                            f, encoding="latin1", engine="python", on_bad_lines="skip"
                        )
                        if df.empty or len(df.columns) == 0:
                            continue
                        if "symbol" in df.columns:
                            dfs.append(df[df["symbol"] == symbol])
                        else:
                            dfs.append(df)
                    except pd.errors.EmptyDataError:
                        continue

    if not dfs:
        raise FileNotFoundError("No matching CSVs found for symbol in ZIP.")
    data = pd.concat(dfs).sort_values("ts_event").reset_index(drop=True)
    return data

df_crwv = load_mbp10_events(zip_path, symbol)
print("✅ Loaded CRWV events")
print(df_crwv.head())
# Out:
# ✅ Loaded CRWV events
#                               ts_event                           ts_event.1  \
# 0  2025-04-03 13:30:00.012155347+00:00  2025-04-03 13:30:00.012155347+00:00
# 1  2025-04-03 13:30:00.012155347+00:00  2025-04-03 13:30:00.012155347+00:00
# 2  2025-04-03 13:30:00.012155347+00:00  2025-04-03 13:30:00.012155347+00:00
# 3  2025-04-03 13:30:00.012344442+00:00  2025-04-03 13:30:00.012344442+00:00
# 4  2025-04-03 13:30:00.012800457+00:00  2025-04-03 13:30:00.012800457+00:00
#
#    rtype  publisher_id  instrument_id action side  depth  price  size  ...  \
# 0     10             2          20613      T    B      0  55.40    99  ...
# 1     10             2          20613      T    B      0  55.40   100  ...
# 2     10             2          20613      T    N      0  55.40   551  ...
# 3     10             2          20613      A    A      0  55.40   100  ...
# 4     10             2          20613      A    B      0  55.39   100  ...
#
#    ask_sz_08  bid_ct_08  ask_ct_08  bid_px_09  ask_px_09  bid_sz_09  \
# 0          4          1          1      54.55      56.70        100
# 1          4          1          1      54.55      56.70        100
# 2         10          1          1      54.55      56.91        100
# 3          4          1          1      54.55      56.70        100
# 4          4          1          1      54.57      56.70        400
#
#    ask_sz_09  bid_ct_09  ask_ct_09  symbol
# 0         10          1          1    CRWV
# 1         10          1          1    CRWV
# 2        100          1          1    CRWV
# 3         10          1          1    CRWV
# 4         10          1          1    CRWV
#
# [5 rows x 74 columns]

# %%
# 📦 3️⃣ Reconstruct the limit order book — FINAL SAFE VERSION

import numpy as np

df_raw = df_crwv.copy()  # make sure we use the loaded CRWV data

levels = range(10)
bid_px = np.full(10, np.nan)
bid_sz = np.zeros(10)
ask_px = np.full(10, np.nan)
ask_sz = np.zeros(10)

snapshots = []
current_minute = None
row_counter = 0
snapshot_every = 5000

for _, row in df_raw.iterrows():
    try:
        ts = pd.to_datetime(row["ts_event"], utc=True)
    except Exception as e:
        print(f"Skipping row due to timestamp error: {e}")
        continue

    minute = ts.floor("min")  # 'T' is deprecated, use 'min'

    depth = int(row["depth"]) if not pd.isna(row["depth"]) else None
    side = str(row["side"]).strip()
    action = str(row["action"]).lower().strip()
    price = row["price"] if not pd.isna(row["price"]) else None
    size = row["size"] if not pd.isna(row["size"]) else 0

    if row_counter < 5:
        print(f"ts: {ts}, depth: {depth}, side: {side}, action: {action}, price: {price}, size: {size}")

    if depth is not None and 0 <= depth < 10 and price is not None:
        if side == "B":
            if action in ["add", "modify", "a", "m"]:
                bid_px[depth] = price
                bid_sz[depth] = size
            elif action in ["cancel", "c"]:
                bid_sz[depth] = max(0, bid_sz[depth] - size)
        elif side == "A":
            if action in ["add", "modify", "a", "m"]:
                ask_px[depth] = price
                ask_sz[depth] = size
            elif action in ["cancel", "c"]:
                ask_sz[depth] = max(0, ask_sz[depth] - size)

    row_counter += 1

    if (current_minute != minute) or (row_counter % snapshot_every == 0):
        snap = {
            "timestamp": minute,
            **{f"bid_px_{i:02d}": bid_px[i] for i in levels},
            **{f"bid_sz_{i:02d}": bid_sz[i] for i in levels},
            **{f"ask_px_{i:02d}": ask_px[i] for i in levels},
            **{f"ask_sz_{i:02d}": ask_sz[i] for i in levels},
        }
        snapshots.append(snap)
        current_minute = minute

print(f"✅ Total snapshots: {len(snapshots)}")

book_df_crwv = pd.DataFrame(snapshots).set_index("timestamp").ffill()
print(f"✅ Final book shape: {book_df_crwv.shape}")
print(book_df_crwv.head())
# Out:
# ts: 2025-04-03 13:30:00.012155347+00:00, depth: 0, side: B, action: t, price: 55.4, size: 99
# ts: 2025-04-03 13:30:00.012155347+00:00, depth: 0, side: B, action: t, price: 55.4, size: 100
# ts: 2025-04-03 13:30:00.012155347+00:00, depth: 0, side: N, action: t, price: 55.4, size: 551
# ts: 2025-04-03 13:30:00.012344442+00:00, depth: 0, side: A, action: a, price: 55.4, size: 100
# ts: 2025-04-03 13:30:00.012800457+00:00, depth: 0, side: B, action: a, price: 55.39, size: 100
# ✅ Total snapshots: 8562
# ✅ Final book shape: (8562, 40)
#                            bid_px_00  bid_px_01  bid_px_02  bid_px_03  \
# timestamp
# 2025-04-03 13:30:00+00:00        NaN        NaN        NaN        NaN
# 2025-04-03 13:31:00+00:00      54.50      54.50      54.65      54.69
# 2025-04-03 13:32:00+00:00      53.24      53.51      53.49      53.48
# 2025-04-03 13:32:00+00:00      53.58      53.55      53.50      53.50
# 2025-04-03 13:33:00+00:00      53.52      53.55      53.57      53.46
#
#                            bid_px_04  bid_px_05  bid_px_06  bid_px_07  \
# timestamp
# 2025-04-03 13:30:00+00:00        NaN        NaN        NaN        NaN
# 2025-04-03 13:31:00+00:00        NaN      54.70      54.75        NaN
# 2025-04-03 13:32:00+00:00        NaN      53.47      53.92      53.50
# 2025-04-03 13:32:00+00:00      53.28      53.32      53.46      53.25
# 2025-04-03 13:33:00+00:00      53.39      53.32      53.37      53.25
#
#                            bid_px_08  bid_px_09  ...  ask_sz_00  ask_sz_01  \
# timestamp                                        ...
# 2025-04-03 13:30:00+00:00        NaN        NaN  ...        0.0        0.0
# 2025-04-03 13:31:00+00:00        NaN      54.40  ...        0.0        0.0
# 2025-04-03 13:32:00+00:00      53.66      53.40  ...      100.0        0.0
# 2025-04-03 13:32:00+00:00      53.66      53.40  ...       27.0        5.0
# 2025-04-03 13:33:00+00:00      53.43      53.27  ...      100.0        0.0
#
#                            ask_sz_02  ask_sz_03  ask_sz_04  ask_sz_05  \
# timestamp
# 2025-04-03 13:30:00+00:00        0.0        0.0        0.0        0.0
# 2025-04-03 13:31:00+00:00        0.0      100.0       63.0        0.0
# 2025-04-03 13:32:00+00:00        0.0        0.0      100.0        0.0
# 2025-04-03 13:32:00+00:00      100.0       20.0        0.0        0.0
# 2025-04-03 13:33:00+00:00       50.0      100.0        0.0        5.0
#
#                            ask_sz_06  ask_sz_07  ask_sz_08  ask_sz_09
# timestamp
# 2025-04-03 13:30:00+00:00        0.0        0.0        0.0        0.0
# 2025-04-03 13:31:00+00:00       70.0        0.0      100.0       73.0
# 2025-04-03 13:32:00+00:00      100.0        0.0        0.0      100.0
# 2025-04-03 13:32:00+00:00        0.0        0.0        0.0        0.0
# 2025-04-03 13:33:00+00:00        0.0        0.0        0.0        0.0
#
# [5 rows x 40 columns]

# %%
import numpy as np
import pandas as pd

# Sizes of hypothetical market orders (in shares)
market_sizes = [100, 500, 1000, 2000, 5000]

# Storage for results
impact_records = []

# Loop through each snapshot in the book
for ts, row in book_df_crwv.iterrows():
    ask_px = [row[f"ask_px_{i:02d}"] for i in range(10)]
    ask_sz = [row[f"ask_sz_{i:02d}"] for i in range(10)]

    # Skip invalid snapshots
    if np.isnan(ask_px[0]) or sum(ask_sz) == 0:
        impact_records.append([np.nan] * len(market_sizes))
        continue

    row_impact = []

    for size in market_sizes:
        remaining = size
        total_cost = 0.0

        for px, sz in zip(ask_px, ask_sz):
            if np.isnan(px) or sz == 0:
                continue
            take = min(remaining, sz)
            total_cost += take * px
            remaining -= take
            if remaining <= 0:
                break

        if remaining > 0:
            row_impact.append(np.nan)  # Not enough depth to fill order
        else:
            avg_fill_price = total_cost / size
            impact = avg_fill_price - ask_px[0]  # Impact vs best ask
            row_impact.append(impact)

    impact_records.append(row_impact)

# Create impact DataFrame
impact_df = pd.DataFrame(impact_records, columns=market_sizes, index=book_df_crwv.index)

# Show preview
print(impact_df.head())

# Optional: Save result
impact_df.to_csv("crwv_impact.csv")
print("✅ Step 3 Complete: Simulated market impact saved to crwv_impact.csv")
# Out:
#                              100   500   1000  2000  5000
# timestamp
# 2025-04-03 13:30:00+00:00     NaN   NaN   NaN   NaN   NaN
# 2025-04-03 13:31:00+00:00  0.2100   NaN   NaN   NaN   NaN
# 2025-04-03 13:32:00+00:00  0.0000   NaN   NaN   NaN   NaN
# 2025-04-03 13:32:00+00:00  0.0562   NaN   NaN   NaN   NaN
# 2025-04-03 13:33:00+00:00  0.0000   NaN   NaN   NaN   NaN
# ✅ Step 3 Complete: Simulated market impact saved to crwv_impact.csv

# %%
import numpy as np
import pandas as pd
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

# Load Step 3 output if not already in memory
impact_df = pd.read_csv("crwv_impact.csv", index_col=0)

# 1. Calculate average market impact per order size
avg_impact = impact_df.mean(skipna=True)
order_sizes = avg_impact.index.astype(int).values
impacts = avg_impact.values

# 2. Remove NaNs (in case some sizes couldn't be filled)
mask = ~np.isnan(impacts)
Q = order_sizes[mask]
I = impacts[mask]

# 3. Power-law model function
def power_law(q, alpha, beta):
    return alpha * q**beta

# 4. Fit the model
params, _ = curve_fit(power_law, Q, I, p0=[1e-3, 0.5], maxfev=10000)
alpha, beta = params

# 5. Predict for plot
Q_fit = np.linspace(Q.min(), Q.max(), 100)
I_fit = power_law(Q_fit, alpha, beta)

# 6. Plot the fit
plt.figure(figsize=(8, 5))
plt.plot(Q, I, 'o', label="Observed avg. impact")
plt.plot(Q_fit, I_fit, '-', label=f"Fit: Impact = {alpha:.4f}·Q^{beta:.4f}")
plt.xscale('log')
plt.yscale('log')
plt.xlabel("Market Order Size (Q)")
plt.ylabel("Average Market Impact")
plt.title("Power-Law Fit to Market Impact Curve")
plt.grid(True, which="both", ls="--")
plt.legend()
plt.tight_layout()
plt.savefig("crwv_impact_fit.png")
plt.show()

# 7. Output parameters
print(f"✅ Fitted parameters:\n   α (alpha) = {alpha:.4f}\n   β (beta) = {beta:.4f}")
# Out:
# ✅ Fitted parameters:
#    α (alpha) = 0.0537
#    β (beta) = 0.1542

# %%
import os
import zipfile
import pandas as pd

symbol = "FROG"
zip_path = r"C:\Users\ajsty\OneDrive\Desktop\new\Data-20250726T124359Z-1-001\Data\FROG.zip"

def load_mbp10_events(zip_file, symbol):
    dfs = []
    with zipfile.ZipFile(zip_file, "r") as zf:
        for fname in zf.namelist():
            if fname.endswith(".csv") and symbol in fname:
                with zf.open(fname) as f:
                    try:
                        df = pd.read_csv(
                            f, encoding="latin1", engine="python", on_bad_lines="skip"
                        )
                        if df.empty or len(df.columns) == 0:
                            continue
                        if "symbol" in df.columns:
                            dfs.append(df[df["symbol"] == symbol])
                        else:
                            dfs.append(df)
                    except pd.errors.EmptyDataError:
                        continue

    if not dfs:
        raise FileNotFoundError("No matching CSVs found for symbol in ZIP.")
    data = pd.concat(dfs).sort_values("ts_event").reset_index(drop=True)
    return data

df_frog = load_mbp10_events(zip_path, symbol)
print("✅ Loaded FROG events")
print(df_frog.head())
# Out:
# ✅ Loaded FROG events
#                               ts_event                           ts_event.1  \
# 0  2025-04-03 13:30:00.125395235+00:00  2025-04-03 13:30:00.125395235+00:00
# 1  2025-04-03 13:30:00.125739764+00:00  2025-04-03 13:30:00.125739764+00:00
# 2  2025-04-03 13:30:00.125745044+00:00  2025-04-03 13:30:00.125745044+00:00
# 3  2025-04-03 13:30:00.170027597+00:00  2025-04-03 13:30:00.170027597+00:00
# 4  2025-04-03 13:30:00.404726961+00:00  2025-04-03 13:30:00.404726961+00:00
#
#    rtype  publisher_id  instrument_id action side  depth  price  size  ...  \
# 0     10             2           6292      C    B      4  29.70   100  ...
# 1     10             2           6292      A    A      3  32.79   100  ...
# 2     10             2           6292      A    B      4  29.74   100  ...
# 3     10             2           6292      A    B      3  29.89   100  ...
# 4     10             2           6292      A    B      7  29.13   100  ...
#
#    ask_sz_08  bid_ct_08  ask_ct_08  bid_px_09  ask_px_09  bid_sz_09  \
# 0          4          1          1      28.49      33.92        100
# 1        800          1          1      28.49      33.85        100
# 2        800          1          1      28.96      33.85        800
# 3        800          1          1      28.97      33.85        100
# 4        800          1          1      29.00      33.85         20
#
#    ask_sz_09  bid_ct_09  ask_ct_09  symbol
# 0        100          1          1    FROG
# 1          4          1          1    FROG
# 2          4          1          1    FROG
# 3          4          1          1    FROG
# 4          4          1          1    FROG
#
# [5 rows x 74 columns]

# %%
import numpy as np
import pandas as pd

def reconstruct_book(df, levels=10):
    # Initialize book storage
    book_snapshots = []
    timestamps = []

    # Book state: price and size arrays
    bid_px = np.full(levels, np.nan)
    bid_sz = np.zeros(levels)
    ask_px = np.full(levels, np.nan)
    ask_sz = np.zeros(levels)

    # Group by each second for snapshotting
    df['ts_event'] = pd.to_datetime(df['ts_event'])
    for i, row in df.iterrows():
        ts = row["ts_event"]
        depth = int(row["depth"])
        side = row["side"].upper()
        action = row["action"].lower()
        price = float(row["price"])
        size = float(row["size"])

        if depth >= levels or depth < 0:
            continue

        if side == "B":
            px_array = bid_px
            sz_array = bid_sz
        elif side == "A":
            px_array = ask_px
            sz_array = ask_sz
        else:
            continue

        if action == "a":  # Add
            px_array[depth] = price
            sz_array[depth] = size
        elif action == "c":  # Cancel
            if px_array[depth] == price:
                sz_array[depth] = max(0, sz_array[depth] - size)
        elif action == "d":  # Delete
            if px_array[depth] == price:
                px_array[depth] = np.nan
                sz_array[depth] = 0
        elif action == "t":  # Trade
            if px_array[depth] == price:
                sz_array[depth] = max(0, sz_array[depth] - size)
        else:
            continue

        # Create snapshot every second
        minute = ts.floor("1min")
        if len(book_snapshots) == 0 or timestamps[-1] != minute:
            snapshot = {}
            for i in range(levels):
                snapshot[f"bid_px_{i:02d}"] = bid_px[i]
                snapshot[f"bid_sz_{i:02d}"] = bid_sz[i]
                snapshot[f"ask_px_{i:02d}"] = ask_px[i]
                snapshot[f"ask_sz_{i:02d}"] = ask_sz[i]
            book_snapshots.append(snapshot)
            timestamps.append(minute)

    book_df = pd.DataFrame(book_snapshots, index=pd.to_datetime(timestamps))
    return book_df

book_df_frog = reconstruct_book(df_frog)
print(f"✅ Total snapshots: {len(book_df_frog)}")
print(f"✅ Final book shape: {book_df_frog.shape}")
print(book_df_frog.head())

# Optional: Save
book_df_frog.to_csv("frog_book.csv")
print("✅ Step 2 Complete: Reconstructed book saved to frog_book.csv")
# Out:
# ✅ Total snapshots: 8156
# ✅ Final book shape: (8156, 40)
#                            bid_px_00  bid_sz_00  ask_px_00  ask_sz_00  \
# 2025-04-03 13:30:00+00:00        NaN        0.0        NaN        0.0
# 2025-04-03 13:31:00+00:00      31.07      100.0      31.50        0.0
# 2025-04-03 13:32:00+00:00      31.41      100.0      31.87      100.0
# 2025-04-03 13:33:00+00:00      31.41        0.0      31.87      100.0
# 2025-04-03 13:34:00+00:00      31.41        0.0      31.87        3.0
#
#                            bid_px_01  bid_sz_01  ask_px_01  ask_sz_01  \
# 2025-04-03 13:30:00+00:00        NaN        0.0        NaN        0.0
# 2025-04-03 13:31:00+00:00      31.04      100.0      31.54        5.0
# 2025-04-03 13:32:00+00:00      31.15      200.0      31.91        0.0
# 2025-04-03 13:33:00+00:00      31.15      200.0      31.91        0.0
# 2025-04-03 13:34:00+00:00      31.24      200.0      31.91        0.0
#
#                            bid_px_02  bid_sz_02  ...  ask_px_07  ask_sz_07  \
# 2025-04-03 13:30:00+00:00        NaN        0.0  ...        NaN        0.0
# 2025-04-03 13:31:00+00:00      30.83      100.0  ...        NaN        0.0
# 2025-04-03 13:32:00+00:00      31.15      100.0  ...      32.19      100.0
# 2025-04-03 13:33:00+00:00      31.15      100.0  ...      32.19      100.0
# 2025-04-03 13:34:00+00:00      31.15      100.0  ...      32.19      100.0
#
#                            bid_px_08  bid_sz_08  ask_px_08  ask_sz_08  \
# 2025-04-03 13:30:00+00:00        NaN        0.0        NaN        0.0
# 2025-04-03 13:31:00+00:00      30.38      100.0      33.15      100.0
# 2025-04-03 13:32:00+00:00      30.38      100.0      33.15      100.0
# 2025-04-03 13:33:00+00:00      30.38      100.0      33.15      100.0
# 2025-04-03 13:34:00+00:00      30.38      100.0      33.15      100.0
#
#                            bid_px_09  bid_sz_09  ask_px_09  ask_sz_09
# 2025-04-03 13:30:00+00:00        NaN        0.0        NaN        0.0
# 2025-04-03 13:31:00+00:00      30.67      200.0      33.44      100.0
# 2025-04-03 13:32:00+00:00      30.59      800.0      33.44      100.0
# 2025-04-03 13:33:00+00:00      30.59      800.0      33.44      100.0
# 2025-04-03 13:34:00+00:00      30.59      800.0      33.44      100.0
#
# [5 rows x 40 columns]
# ✅ Step 2 Complete: Reconstructed book saved to frog_book.csv

# %%
import numpy as np
import pandas as pd

# Load the reconstructed book from step 2
book_df_frog = pd.read_csv("frog_book.csv", index_col=0, parse_dates=True)

# Sizes of hypothetical market orders (in shares)
market_sizes = [100, 500, 1000, 2000, 5000]

# Storage for results
impact_records = []

# Loop through each snapshot in the book
for ts, row in book_df_frog.iterrows():
    ask_px = [row[f"ask_px_{i:02d}"] for i in range(10)]
    ask_sz = [row[f"ask_sz_{i:02d}"] for i in range(10)]

    # Skip invalid snapshots
    if np.isnan(ask_px[0]) or sum(ask_sz) == 0:
        impact_records.append([np.nan] * len(market_sizes))
        continue

    row_impact = []

    for size in market_sizes:
        remaining = size
        total_cost = 0.0

        for px, sz in zip(ask_px, ask_sz):
            if np.isnan(px) or sz == 0:
                continue
            take = min(remaining, sz)
            total_cost += take * px
            remaining -= take
            if remaining <= 0:
                break

        if remaining > 0:
            row_impact.append(np.nan)  # Not enough depth to fill order
        else:
            avg_fill_price = total_cost / size
            impact = avg_fill_price - ask_px[0]  # Impact vs best ask
            row_impact.append(impact)

    impact_records.append(row_impact)

# Create impact DataFrame
impact_df_frog = pd.DataFrame(impact_records, columns=market_sizes, index=book_df_frog.index)

# Show preview
print(impact_df_frog.head())

# Save result
impact_df_frog.to_csv("frog_impact.csv")
print("✅ Step 3 Complete: Simulated market impact saved to frog_impact.csv")
# Out:
#                              100     500     1000      2000  5000
# 2025-04-03 13:30:00+00:00     NaN     NaN     NaN       NaN   NaN
# 2025-04-03 13:31:00+00:00  0.3535  0.4616  0.4708  0.692625   NaN
# 2025-04-03 13:32:00+00:00  0.0000  0.2460     NaN       NaN   NaN
# 2025-04-03 13:33:00+00:00  0.0000  0.2340     NaN       NaN   NaN
# 2025-04-03 13:34:00+00:00  0.3298  0.3504     NaN       NaN   NaN
# ✅ Step 3 Complete: Simulated market impact saved to frog_impact.csv

# %%
import pandas as pd
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

# Load the impact CSV
impact_df = pd.read_csv("frog_impact.csv", index_col=0, parse_dates=True)

# Define power-law function
def power_law(x, beta, alpha):
    return beta * np.power(x, alpha)

# Prepare the data for fitting
sizes = impact_df.columns.astype(int)  # [100, 500, 1000, ...]
x_data = np.concatenate([[s] * len(impact_df) for s in sizes])
y_data = np.concatenate([impact_df[str(s)].values for s in sizes])

# Remove NaNs
mask = ~np.isnan(y_data)
x_data = x_data[mask]
y_data = y_data[mask]

# Fit using curve_fit
(beta_est, alpha_est), _ = curve_fit(power_law, x_data, y_data, p0=[1e-4, 0.5])
print(f"✅ Fitted β: {beta_est:.4f}, α: {alpha_est:.4f}")

# Plot (log-log scale)
plt.figure(figsize=(8, 6))
plt.scatter(x_data, y_data, alpha=0.5, label="Data")
x_fit = np.linspace(100, 5000, 100)
y_fit = power_law(x_fit, beta_est, alpha_est)
plt.plot(x_fit, y_fit, color="red", label=f"Fit: β={beta_est:.2e}, α={alpha_est:.2f}")
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Order Size (shares)")
plt.ylabel("Temporary Impact")
plt.title("Power Law Fit — FROG")
plt.legend()
plt.grid(True, which='both')
plt.tight_layout()
plt.show()
# Out:
# ✅ Fitted β: 0.0059, α: 0.4784

# %%
import os
import zipfile
import pandas as pd

symbol = "SOUN"
zip_path = r"C:\Users\ajsty\OneDrive\Desktop\new\Data-20250726T124359Z-1-001\Data\SOUN.zip"

def load_mbp10_events(zip_file, symbol):
    dfs = []
    with zipfile.ZipFile(zip_file, "r") as zf:
        for fname in zf.namelist():
            if fname.endswith(".csv") and symbol in fname:
                with zf.open(fname) as f:
                    try:
                        df = pd.read_csv(
                            f, encoding="latin1", engine="python", on_bad_lines="skip"
                        )
                        if df.empty or len(df.columns) == 0:
                            continue
                        if "symbol" in df.columns:
                            dfs.append(df[df["symbol"] == symbol])
                        else:
                            dfs.append(df)
                    except pd.errors.EmptyDataError:
                        continue

    if not dfs:
        raise FileNotFoundError("No matching CSVs found for symbol in ZIP.")
    data = pd.concat(dfs).sort_values("ts_event").reset_index(drop=True)
    return data

df_soun = load_mbp10_events(zip_path, symbol)
print("✅ Loaded SOUN events")
print(df_soun.head())
# Out:
# ✅ Loaded SOUN events
#                               ts_event                           ts_event.1  \
# 0  2025-04-03 13:30:00.005642878+00:00  2025-04-03 13:30:00.005642878+00:00
# 1  2025-04-03 13:30:00.005948702+00:00  2025-04-03 13:30:00.005948702+00:00
# 2  2025-04-03 13:30:00.013021640+00:00  2025-04-03 13:30:00.013021640+00:00
# 3  2025-04-03 13:30:00.015953598+00:00  2025-04-03 13:30:00.015953598+00:00
# 4  2025-04-03 13:30:00.016252285+00:00  2025-04-03 13:30:00.016252285+00:00
#
#    rtype  publisher_id  instrument_id action side  depth  price  size  ...  \
# 0     10             2          14993      A    B      1   7.88   100  ...
# 1     10             2          14993      A    A      1   7.92   100  ...
# 2     10             2          14993      C    A      0   7.91    84  ...
# 3     10             2          14993      A    A      1   7.92   100  ...
# 4     10             2          14993      T    A      0   7.89    92  ...
#
#    ask_sz_08  bid_ct_08  ask_ct_08  bid_px_09  ask_px_09  bid_sz_09  \
# 0         84         28          3       7.79       8.07         15
# 1         84         28          3       7.79       8.07         15
# 2         84         28          3       7.79       8.07         15
# 3         84         28          3       7.79       8.07         15
# 4         84         28          3       7.79       8.07         15
#
#    ask_sz_09  bid_ct_09  ask_ct_09  symbol
# 0         29          5          1    SOUN
# 1         29          5          1    SOUN
# 2         29          5          1    SOUN
# 3         29          5          1    SOUN
# 4         29          5          1    SOUN
#
# [5 rows x 74 columns]

# %%
import numpy as np
import pandas as pd

df_raw = df_soun.copy()  # 👈 Use the loaded SOUN data

levels = range(10)
bid_px = np.full(10, np.nan)
bid_sz = np.zeros(10)
ask_px = np.full(10, np.nan)
ask_sz = np.zeros(10)

snapshots = []
current_minute = None
row_counter = 0
snapshot_every = 5000

for _, row in df_raw.iterrows():
    try:
        ts = pd.to_datetime(row["ts_event"], utc=True)
    except Exception as e:
        print(f"Skipping row due to timestamp error: {e}")
        continue

    minute = ts.floor("1T")

    depth = int(row["depth"]) if not pd.isna(row["depth"]) else None
    side = str(row["side"]).strip()
    action = str(row["action"]).lower().strip()
    price = row["price"] if not pd.isna(row["price"]) else None
    size = row["size"] if not pd.isna(row["size"]) else 0

    if row_counter < 5:
        print(f"ts: {ts}, depth: {depth}, side: {side}, action: {action}, price: {price}, size: {size}")

    if depth is not None and 0 <= depth < 10 and price is not None:
        if side == "B":
            if action in ["add", "modify", "a", "m"]:
                bid_px[depth] = price
                bid_sz[depth] = size
            elif action in ["cancel", "c"]:
                bid_sz[depth] = max(0, bid_sz[depth] - size)
        elif side == "A":
            if action in ["add", "modify", "a", "m"]:
                ask_px[depth] = price
                ask_sz[depth] = size
            elif action in ["cancel", "c"]:
                ask_sz[depth] = max(0, ask_sz[depth] - size)

    row_counter += 1

    if (current_minute != minute) or (row_counter % snapshot_every == 0):
        snap = {
            "timestamp": minute,
            **{f"bid_px_{i:02d}": bid_px[i] for i in levels},
            **{f"bid_sz_{i:02d}": bid_sz[i] for i in levels},
            **{f"ask_px_{i:02d}": ask_px[i] for i in levels},
            **{f"ask_sz_{i:02d}": ask_sz[i] for i in levels},
        }
        snapshots.append(snap)
        current_minute = minute

print(f"✅ Total snapshots: {len(snapshots)}")

book_df_soun = pd.DataFrame(snapshots).set_index("timestamp").ffill()
book_df_soun.to_csv("soun_book.csv")
print(f"✅ Final book shape: {book_df_soun.shape}")
print(book_df_soun.head())
print("✅ Step 2 Complete: Reconstructed book saved to soun_book.csv")
# Out:
# C:\Users\ajsty\AppData\Local\Temp\ipykernel_25212\3701082494.py:24: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   minute = ts.floor("1T")
# ts: 2025-04-03 13:30:00.005642878+00:00, depth: 1, side: B, action: a, price: 7.88, size: 100
# ts: 2025-04-03 13:30:00.005948702+00:00, depth: 1, side: A, action: a, price: 7.92, size: 100
# ts: 2025-04-03 13:30:00.013021640+00:00, depth: 0, side: A, action: c, price: 7.91, size: 84
# ts: 2025-04-03 13:30:00.015953598+00:00, depth: 1, side: A, action: a, price: 7.92, size: 100
# ts: 2025-04-03 13:30:00.016252285+00:00, depth: 0, side: A, action: t, price: 7.89, size: 92

# %%
# 📦 2️⃣ Load MBP-10 reventsaw 
# --------------------------------------------------
zip_files = [r"C:\Users\aryan\Downloads\FROG.zip"]
def load_mbp10_events(zip_files, symbol):
    dfs = []
    for zpath in zip_files:
        if not os.path.exists(zpath):
            continue
        with zipfile.ZipFile(zpath, "r") as zf:
            for fname in zf.namelist():
                if fname.endswith(".csv") and symbol in fname:
                    with zf.open(fname) as f:
                        df = pd.read_csv(
                            f, encoding="latin1",
                            engine="python", on_bad_lines="skip"
                        )
                        if "symbol" in df.columns:
                            dfs.append(df[df["symbol"] == symbol])
                        else:
                            dfs.append(df)
    if not dfs:
        raise FileNotFoundError("No files found for symbol.")
    data = pd.concat(dfs).sort_values("ts_event").reset_index(drop=True)
    return data

df_frog = load_mbp10_events(zip_files, "FROG")
print(df_frog.head())

# --------------------------------------------------
# Out:
#                               ts_event                           ts_event.1  \
# 0  2025-04-03 13:30:00.125395235+00:00  2025-04-03 13:30:00.125395235+00:00
# 1  2025-04-03 13:30:00.125739764+00:00  2025-04-03 13:30:00.125739764+00:00
# 2  2025-04-03 13:30:00.125745044+00:00  2025-04-03 13:30:00.125745044+00:00
# 3  2025-04-03 13:30:00.170027597+00:00  2025-04-03 13:30:00.170027597+00:00
# 4  2025-04-03 13:30:00.404726961+00:00  2025-04-03 13:30:00.404726961+00:00
#
#    rtype  publisher_id  instrument_id action side  depth  price  size  ...  \
# 0     10             2           6292      C    B      4  29.70   100  ...
# 1     10             2           6292      A    A      3  32.79   100  ...
# 2     10             2           6292      A    B      4  29.74   100  ...
# 3     10             2           6292      A    B      3  29.89   100  ...
# 4     10             2           6292      A    B      7  29.13   100  ...
#
#    ask_sz_08  bid_ct_08  ask_ct_08  bid_px_09  ask_px_09  bid_sz_09  \
# 0          4          1          1      28.49      33.92        100
# 1        800          1          1      28.49      33.85        100
# 2        800          1          1      28.96      33.85        800
# 3        800          1          1      28.97      33.85        100
# 4        800          1          1      29.00      33.85         20
#
#    ask_sz_09  bid_ct_09  ask_ct_09  symbol
# 0        100          1          1    FROG
# 1          4          1          1    FROG
# 2          4          1          1    FROG
# 3          4          1          1    FROG
# 4          4          1          1    FROG
#
# [5 rows x 74 columns]

# %%
import os
import zipfile
import pandas as pd

zip_file = r"C:\\Users\\aryan\\Downloads\\SOUN.zip"
output_file = r"C:\\Users\\aryan\\Downloads\\soun_full.csv"

symbol = "SOUN"

first_chunk = True

with zipfile.ZipFile(zip_file, "r") as zf:
    for fname in zf.namelist():
        if fname.endswith(".csv"):
            print(f"Reading: {fname}")
            with zf.open(fname) as f:
                for chunk in pd.read_csv(
                    f,
                    encoding="latin1",
                    engine="python",
                    on_bad_lines="skip",
                    chunksize=500_000
                ):
                    # Filter by symbol if present
                    if "symbol" in chunk.columns:
                        chunk = chunk[chunk["symbol"] == symbol]

                    if not chunk.empty:
                        # Write to disk chunk by chunk
                        chunk.to_csv(output_file, mode="a", header=first_chunk, index=False)
                        first_chunk = False

print(f"✅ Done! Written to: {output_file}")

# Load a small piece just to check
df_soun = pd.read_csv(output_file, nrows=5)
print(df_soun)
# Out:
# Reading: SOUN_2025-05-02 00:00:00+00:00.csv
# Reading: __MACOSX/._SOUN_2025-05-02 00:00:00+00:00.csv
# Reading: SOUN_2025-05-01 00:00:00+00:00.csv
# Reading: __MACOSX/._SOUN_2025-05-01 00:00:00+00:00.csv
# Reading: SOUN_2025-04-30 00:00:00+00:00.csv
# Reading: __MACOSX/._SOUN_2025-04-30 00:00:00+00:00.csv
# Reading: SOUN_2025-04-29 00:00:00+00:00.csv
# Reading: __MACOSX/._SOUN_2025-04-29 00:00:00+00:00.csv
# Reading: SOUN_2025-04-28 00:00:00+00:00.csv
# Reading: __MACOSX/._SOUN_2025-04-28 00:00:00+00:00.csv
# Reading: SOUN_2025-04-25 00:00:00+00:00.csv
# Reading: __MACOSX/._SOUN_2025-04-25 00:00:00+00:00.csv
# Reading: SOUN_2025-04-24 00:00:00+00:00.csv
# Reading: __MACOSX/._SOUN_2025-04-24 00:00:00+00:00.csv
# Reading: SOUN_2025-04-23 00:00:00+00:00.csv
# Reading: __MACOSX/._SOUN_2025-04-23 00:00:00+00:00.csv
# Reading: SOUN_2025-04-22 00:00:00+00:00.csv
# Reading: __MACOSX/._SOUN_2025-04-22 00:00:00+00:00.csv
# Reading: SOUN_2025-04-21 00:00:00+00:00.csv
# Reading: __MACOSX/._SOUN_2025-04-21 00:00:00+00:00.csv
# Reading: SOUN_2025-04-17 00:00:00+00:00.csv
# Reading: __MACOSX/._SOUN_2025-04-17 00:00:00+00:00.csv
# Reading: SOUN_2025-04-16 00:00:00+00:00.csv
# Reading: __MACOSX/._SOUN_2025-04-16 00:00:00+00:00.csv
# Reading: SOUN_2025-04-15 00:00:00+00:00.csv
# Reading: __MACOSX/._SOUN_2025-04-15 00:00:00+00:00.csv
# Reading: SOUN_2025-04-14 00:00:00+00:00.csv
# Reading: __MACOSX/._SOUN_2025-04-14 00:00:00+00:00.csv
# Reading: SOUN_2025-04-11 00:00:00+00:00.csv
# Reading: __MACOSX/._SOUN_2025-04-11 00:00:00+00:00.csv
# Reading: SOUN_2025-04-10 00:00:00+00:00.csv
# Reading: __MACOSX/._SOUN_2025-04-10 00:00:00+00:00.csv
# Reading: SOUN_2025-04-09 00:00:00+00:00.csv
# Reading: __MACOSX/._SOUN_2025-04-09 00:00:00+00:00.csv
# Reading: SOUN_2025-04-08 00:00:00+00:00.csv
# Reading: __MACOSX/._SOUN_2025-04-08 00:00:00+00:00.csv
# Reading: SOUN_2025-04-07 00:00:00+00:00.csv
# Reading: __MACOSX/._SOUN_2025-04-07 00:00:00+00:00.csv
# Reading: SOUN_2025-04-04 00:00:00+00:00.csv
# Reading: __MACOSX/._SOUN_2025-04-04 00:00:00+00:00.csv
# Reading: SOUN_2025-04-03 00:00:00+00:00.csv
# Reading: __MACOSX/._SOUN_2025-04-03 00:00:00+00:00.csv
# ✅ Done! Written to: C:\\Users\\aryan\\Downloads\\soun_full.csv
#                               ts_event                           ts_event.1  \
# 0  2025-05-02 13:30:00.014437085+00:00  2025-05-02 13:30:00.014437085+00:00
# 1  2025-05-02 13:30:00.014437085+00:00  2025-05-02 13:30:00.014437085+00:00
# 2  2025-05-02 13:30:00.014437085+00:00  2025-05-02 13:30:00.014437085+00:00
# 3  2025-05-02 13:30:00.014592343+00:00  2025-05-02 13:30:00.014592343+00:00
# 4  2025-05-02 13:30:00.014604302+00:00  2025-05-02 13:30:00.014604302+00:00
#
#    rtype  publisher_id  instrument_id action side  depth  price  size  ...  \
# 0     10             2          14993      T    A      0   9.29   500  ...
# 1     10             2          14993      T    A      0   9.29    10  ...
# 2     10             2          14993      C    B      0   9.29    10  ...
# 3     10             2          14993      A    A      0   9.52   100  ...
# 4     10             2          14993      A    A      0   9.31    84  ...
#
#    ask_sz_08  bid_ct_08  ask_ct_08  bid_px_09  ask_px_09  bid_sz_09  \
# 0         12          7          1       9.19       9.47        100
# 1         12          7          1       9.19       9.47        100
# 2         12          1          1       9.18       9.47       1401
# 3         12          1          1       9.18       9.46       1401
# 4         12          1          1       9.18       9.46       1401
#
#    ask_sz_09  bid_ct_09  ask_ct_09  symbol
# 0         12          1          1    SOUN
# 1         12          1          1    SOUN
# 2         12          4          1    SOUN
# 3         12          4          1    SOUN
# 4         12          4          1    SOUN
#
# [5 rows x 74 columns]

# %%
# --------------------------------------------------
# 📦 3️⃣ Reconstruct the limit order book — FINAL SAFE VERSION
# --------------------------------------------------

import numpy as np
import pandas as pd

levels = range(10)
bid_px = np.full(10, np.nan)
bid_sz = np.zeros(10)
ask_px = np.full(10, np.nan)
ask_sz = np.zeros(10)

snapshots = []
current_minute = None
row_counter = 0
snapshot_every = 5000

for _, row in df_raw.iterrows():
    try:
        ts = pd.to_datetime(row["ts_event"], utc=True)
    except Exception as e:
        print(f"Skipping row due to timestamp error: {e}")
        continue

    minute = ts.floor("1T")

    depth = int(row["depth"]) if not pd.isna(row["depth"]) else None
    side = str(row["side"]).strip()
    action = str(row["action"]).lower().strip()
    price = row["price"] if not pd.isna(row["price"]) else None
    size = row["size"] if not pd.isna(row["size"]) else 0

    if row_counter < 5:
        print(f"ts: {ts}, depth: {depth}, side: {side}, action: {action}, price: {price}, size: {size}")

    if depth is not None and 0 <= depth < 10 and price is not None:
        if side == "B":
            if action in ["add", "modify", "a", "m"]:
                bid_px[depth] = price
                bid_sz[depth] = size
            elif action in ["cancel", "c"]:
                bid_sz[depth] = max(0, bid_sz[depth] - size)
        elif side == "A":
            if action in ["add", "modify", "a", "m"]:
                ask_px[depth] = price
                ask_sz[depth] = size
            elif action in ["cancel", "c"]:
                ask_sz[depth] = max(0, ask_sz[depth] - size)

    row_counter += 1

    if (current_minute != minute) or (row_counter % snapshot_every == 0):
        snap = {
            "timestamp": minute,
            **{f"bid_px_{i:02d}": bid_px[i] for i in levels},
            **{f"bid_sz_{i:02d}": bid_sz[i] for i in levels},
            **{f"ask_px_{i:02d}": ask_px[i] for i in levels},
            **{f"ask_sz_{i:02d}": ask_sz[i] for i in levels},
        }
        snapshots.append(snap)
        current_minute = minute

print(f"✅ Total snapshots: {len(snapshots)}")

book_df = pd.DataFrame(snapshots).set_index("timestamp").ffill()
print(f"✅ Final book shape: {book_df.shape}")
print(book_df.head())
# Out:
# C:\Users\aryan\AppData\Local\Temp\ipykernel_17904\1931397040.py:26: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   minute = ts.floor("1T")
# ts: 2025-04-03 13:30:00.125395235+00:00, depth: 4, side: B, action: c, price: 29.7, size: 100
# ts: 2025-04-03 13:30:00.125739764+00:00, depth: 3, side: A, action: a, price: 32.79, size: 100
# ts: 2025-04-03 13:30:00.125745044+00:00, depth: 4, side: B, action: a, price: 29.74, size: 100
# ts: 2025-04-03 13:30:00.170027597+00:00, depth: 3, side: B, action: a, price: 29.89, size: 100
# ts: 2025-04-03 13:30:00.404726961+00:00, depth: 7, side: B, action: a, price: 29.13, size: 100
# ✅ Total snapshots: 8279
# ✅ Final book shape: (8279, 40)
#                            bid_px_00  bid_px_01  bid_px_02  bid_px_03  \
# timestamp
# 2025-04-03 13:30:00+00:00        NaN        NaN        NaN        NaN
# 2025-04-03 13:31:00+00:00      31.07      31.04      30.83      30.88
# 2025-04-03 13:32:00+00:00      31.41      31.15      31.15      31.08
# 2025-04-03 13:33:00+00:00      31.41      31.15      31.15      31.08
# 2025-04-03 13:34:00+00:00      31.41      31.24      31.15      31.08
#
#                            bid_px_04  bid_px_05  bid_px_06  bid_px_07  \
# timestamp
# 2025-04-03 13:30:00+00:00        NaN        NaN        NaN        NaN
# 2025-04-03 13:31:00+00:00      30.74       30.9        NaN      29.13
# 2025-04-03 13:32:00+00:00      31.08       30.9      31.08      31.06
# 2025-04-03 13:33:00+00:00      31.08       30.9      31.08      31.06
# 2025-04-03 13:34:00+00:00      31.08       30.9      31.08      31.06
#
#                            bid_px_08  bid_px_09  ...  ask_sz_00  ask_sz_01  \
# timestamp                                        ...
# 2025-04-03 13:30:00+00:00        NaN        NaN  ...        0.0        0.0
# 2025-04-03 13:31:00+00:00      30.38      30.67  ...        0.0        5.0
# 2025-04-03 13:32:00+00:00      30.38      30.59  ...      100.0        0.0
# 2025-04-03 13:33:00+00:00      30.38      30.59  ...      100.0        0.0
# 2025-04-03 13:34:00+00:00      30.38      30.59  ...        3.0        0.0
#
#                            ask_sz_02  ask_sz_03  ask_sz_04  ask_sz_05  \
# timestamp
# 2025-04-03 13:30:00+00:00        0.0        0.0        0.0        0.0
# 2025-04-03 13:31:00+00:00      200.0       94.0      800.0       95.0
# 2025-04-03 13:32:00+00:00        0.0      100.0      100.0      100.0
# 2025-04-03 13:33:00+00:00        0.0      200.0      100.0      100.0
# 2025-04-03 13:34:00+00:00        0.0      100.0      100.0      100.0
#
#                            ask_sz_06  ask_sz_07  ask_sz_08  ask_sz_09
# timestamp
# 2025-04-03 13:30:00+00:00        0.0        0.0        0.0        0.0
# 2025-04-03 13:31:00+00:00     1527.0        0.0        0.0        0.0
# 2025-04-03 13:32:00+00:00        0.0      100.0        0.0        0.0
# 2025-04-03 13:33:00+00:00        0.0      100.0        0.0        0.0
# 2025-04-03 13:34:00+00:00        0.0      100.0        0.0        0.0
#
# [5 rows x 40 columns]

# %%
# 📦 4️⃣ Simulate fills for multiple order sizes
# --------------------------------------------------
def simulate_impact(row, size):
    px = row[[f"ask_px_{i:02d}" for i in levels]].values
    sz = row[[f"ask_sz_{i:02d}" for i in levels]].values
    remaining = size
    cost = 0
    for p, s in zip(px, sz):
        take = min(remaining, s)
        cost += take * p
        remaining -= take
        if remaining <= 0:
            break
    if remaining > 0:
        cost += remaining * px[-1]  # fill remainder at last ask
    exec_price = cost / size
    mid = 0.5 * (row["bid_px_00"] + row["ask_px_00"])
    return exec_price - mid

sizes = [100, 500, 1000, 2000, 5000]
impact_data = {s: [] for s in sizes}

for _, row in book_df.iterrows():
    for s in sizes:
        impact_data[s].append(simulate_impact(row, s))

impact_df = pd.DataFrame(impact_data, index=book_df.index)
print(impact_df.head())

# --------------------------------------------------
# Out:
#                              100      500      1000      2000      5000
# timestamp
# 2025-04-03 13:30:00+00:00     NaN      NaN      NaN       NaN       NaN
# 2025-04-03 13:31:00+00:00  0.5685  0.67480  0.68490  0.909255       NaN
# 2025-04-03 13:32:00+00:00  0.2300  0.43800  1.11900  1.459500  1.663800
# 2025-04-03 13:33:00+00:00  0.2300  0.46400  1.00700  1.403500  1.641400
# 2025-04-03 13:34:00+00:00  0.5598  0.76458  1.28229  1.541145  1.696458

# %%
from scipy.optimize import curve_fit
import numpy as np

def power_law(x, beta, alpha):
    return beta * np.power(x, alpha)

# flatten the data
x_data = np.concatenate([[s] * len(impact_df) for s in sizes])
y_data = np.concatenate([impact_df[s].values for s in sizes])

# remove NaNs
mask = ~np.isnan(y_data)
x_data = x_data[mask]
y_data = y_data[mask]

(beta_est, alpha_est), _ = curve_fit(power_law, x_data, y_data, p0=[1e-4, 0.5])
print(f"✅ Fitted beta: {beta_est:.4f}, alpha: {alpha_est:.4f}")
# Out:
# ✅ Fitted beta: 0.0354, alpha: 0.2519

# %%
# 📦 6️⃣ Plot: Impact vs. Size (log-log)
# --------------------------------------------------
plt.figure(figsize=(8, 6))
plt.scatter(x_data, y_data, alpha=0.5, label="Simulated")
x_fit = np.linspace(100, 5000, 100)
y_fit = power_law(x_fit, beta_est, alpha_est)
plt.plot(x_fit, y_fit, color="red", label=f"Fit: beta={beta_est:.2e}, alpha={alpha_est:.2f}")

plt.xscale("log")
plt.yscale("log")
plt.xlabel("Order size (shares)")
plt.ylabel("Temporary impact")
plt.title(f"Impact vs. Size for {symbol}")
plt.legend()
plt.grid(True, which='both')
plt.show()
